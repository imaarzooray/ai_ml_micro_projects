# %% [markdown]
# <a href="https://colab.research.google.com/github/imaarzooray/ai_ml_micro_projects/blob/main/single_layer_perceptron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5
b= 4
c = a + b
print(a + b)
# Out:
# 9
